# %%
from selenium import webdriver
from bs4  import BeautifulSoup
import time
import csv

#def website(url,filename):
driver = webdriver.Chrome("C:/chromedriver.exe")
url = "https://www.justdial.com/Surendra-Nagar-Gujarat/search?q=Salons-24-Hours&clst=1"
driver.get(url)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(10)

content = driver.page_source
soup = BeautifulSoup(content)
#print(soup)
contents = soup.findAll('span',href=False, attrs={'class':'jcn'})
#print(len(contents))
list_urls = [i.a.get("href") for i in contents]
#print(list_urls)
# Out:
# 0
# []

# %%
driver = webdriver.Chrome("C:/chromedriver.exe")
url = list_urls[0]
#url = "https://www.justdial.com/Surendra-Nagar-Gujarat/Honest-Restaurant-Chotila-Surendranagar/"
driver.get(url)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(10)

content = driver.page_source
soup = BeautifulSoup(content)
#print(soup)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-31-71b92bc6c197> in <module>
#       6 time.sleep(10)
#       7
# ----> 8 content = driver.page_source
#       9 soup = BeautifulSoup(content)
#      10 #print(soup)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
# ...

# %%
contents = soup.find('div',href=False, attrs={'class':'company-details'})

# %%
soup
# Out:
# <html><head><title>Error</title></head><body>
# An error occurred while processing your request.<p>
# Reference #97.d3702c31.1624338336.15fc40d6
#
# </p></body></html>

# %%
list_urls = [i.a.get("href") for i in contents]
#print(list_urls)
# Out:
# ['https://www.justdial.com/Surendra-Nagar-Gujarat/New-Bavaliyas-Men-Hair-Salon-Near-Dholipole-Main-Road-Wadhwancity/9999P2752-2752-180301215236-M3Q8_BZDET?xid=U3VyZW5kcmEgTmFnYXItR3VqYXJhdCBTYWxvbnMtMjQtSG91cnM=', 'https://www.justdial.com/Surendra-Nagar-Gujarat/Imperial-Beauty-Salon-Surendranagar-City/9999P2752-2752-171230053239-E8N7_BZDET?xid=U3VyZW5kcmEgTmFnYXItR3VqYXJhdCBTYWxvbnMtMjQtSG91cnM=', 'https://www.justdial.com/Surendra-Nagar-Gujarat/Sunnys-Salon/9999P2752-2752-180606093238-D6I8_BZDET?xid=U3VyZW5kcmEgTmFnYXItR3VqYXJhdCBTYWxvbnMtMjQtSG91cnM=', 'https://www.justdial.com/Surendra-Nagar-Gujarat/Akshar-Hair-Salon-Halvad/9999P2752-2752-190117180130-R9L4_BZDET?xid=U3VyZW5kcmEgTmFnYXItR3VqYXJhdCBTYWxvbnMtMjQtSG91cnM=', 'https://www.justdial.com/Surendra-Nagar-Gujarat/Beautystar-Hair-And-Beauty-Salon-Jintan-Road-Surendranagar-HO/9999P2752-2752-140201092348-R5Y7_BZDET?xid=U3VyZW5kcmEgTmFnYXItR3VqYXJhdCBTYWxvbnMtMjQtSG91cnM=', 'https://www.justdial.com/Surendra-Nagar-Gujarat/Black-
# ...

# %%
# Out:
# 'https://www.justdial.com/Surendra-Nagar-Gujarat/New-Bavaliyas-Men-Hair-Salon-Near-Dholipole-Main-Road-Wadhwancity/9999P2752-2752-180301215236-M3Q8_BZDET?xid=U3VyZW5kcmEgTmFnYXItR3VqYXJhdCBTYWxvbnMtMjQtSG91cnM='

# %%
    #print(soup)
    contents = soup.findAll('div',href=False, attrs={'class':'col-sm-5 col-xs-8 store-details sp-detail paddingR0'})
    print(len(contents))
    #to find contact no
    switcher = {
        'dc':"+",
        'fe':"(",
        'ji':"9",
        'yz':"1",
        'hg':")",
        'ba':"-",
        'ac':"0",
        'yz':"1",
        'wx':"2",
        'vu':"3",
        'ts':"4",
        'rq':"5",
        'po':"6",
        'nm':"7",
        'lk':"8",
        'ji':"9"
    }
    
    with open(r''+filename+".csv", 'a') as f:
        writer = csv.writer(f)    
        for content in contents:
            name = content.a.text
            address = content.find('span',href=False, attrs={'class':'cont_fl_addr'}).text
            x = str(content.find('p',href=False, attrs={'class':'contact-info'})).split("mobilesv icon-")
            x = [i[0:2] for i in x[1:]]
            c_number = ""
            for i in x:
                c_number += switcher.get(i)
            #print(f"Name: {name}\nAddress: {address}\nContact No: {c_number}\n")
            fields = [name, address, c_number]
            writer.writerow(fields)
    return contents

# %%
from JD import website
pages = 100

for city in ["kheda", "pune", "anand", "panchmahal", "gandhinagar", "surat" ]:
#for city in ["panchmahal", "gandhinagar", "surat" ]:
    for i in range(1,pages):
        url = "https://www.justdial.com/"+ city +"/Salons-Unisex/nct-11207049/page-"+str(i)
        url_split = url.split("/")[3:]
        filename = url_split[0] + "_" + url_split[1]
        if len(website(url,filename)) == 0:
            print("Process Done")
            break
        print("Page No "+ str(i) +" done")
    print("City: ", city)
    print("*"*50)
# Out:
# 15
# Page No 1 done
# 15
# Page No 2 done
# 15
# Page No 3 done
# 15
# Page No 4 done
# 15
# Page No 5 done
# 15
# Page No 6 done
# 15
# Page No 7 done
# 15
# Page No 8 done
# 15
# Page No 9 done
# 15
# Page No 10 done
# 15
# Page No 11 done
# 15
# Page No 12 done
# 15
# Page No 13 done
# 15
# Page No 14 done
# 15
# Page No 15 done
# 15
# Page No 16 done
# 15
# Page No 17 done
# 15
# Page No 18 done
# 15
# Page No 19 done
# 15
# Page No 20 done
# 15
# Page No 21 done
# 15
# Page No 22 done
# 10
# Page No 23 done
# 15
# Page No 24 done
# 15
# Page No 25 done
# 15
# Page No 26 done
# 15
# Page No 27 done
# 15
# Page No 28 done
# 15
# Page No 29 done
# 15
# Page No 30 done
# 15
# Page No 31 done
# 15
# Page No 32 done
# 15
# Page No 33 done
# 15
# Page No 34 done
# 15
# Page No 35 done
# 15
# Page No 36 done
# 15
# Page No 37 done
# 15
# Page No 38 done
# 15
# Page No 39 done
# 15
# Page No 40 done
# 15
# Page No 41 done
# 15
# Page No 42 done
# 15
# Page No 43 done
# 15
# ...
