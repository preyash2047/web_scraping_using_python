# %%
from JD import website
pages = 100

for city in ["kheda", "pune", "anand", "panchmahal", "gandhinagar", "surat" ]:
    for i in range(1,pages):
        url = "https://www.justdial.com/"+ city +"/Salons-24-Hours/nct-11201548/page-"+str(i)
        url_split = url.split("/")[3:]
        filename = url_split[0] + "_" + url_split[1]
        if len(website(url,filename)) == 0:
            print("Process Done")
            break
        print("Page No "+ str(i) +" done")
    print("City: ", city)
    print("*"*50)
# Out:
# 15
# Page No 1 done
# 15
# Page No 2 done
# 15
# Page No 3 done
# 15
# Page No 4 done
# 15
# Page No 5 done
# 15
# Page No 6 done
# 15
# Page No 7 done
# 15
# Page No 8 done
# 15
# Page No 9 done
# 15
# Page No 10 done
# 15
# Page No 11 done
# 15
# Page No 12 done
# 15
# Page No 13 done
# 15
# Page No 14 done
# 15
# Page No 15 done
# 15
# Page No 16 done
# 15
# Page No 17 done
# 15
# Page No 18 done
# 15
# Page No 19 done
# 15
# Page No 20 done
# 15
# Page No 21 done
# 15
# Page No 22 done
# 15
# Page No 23 done
# 15
# Page No 24 done
# 15
# Page No 25 done
# 15
# Page No 26 done
# 15
# Page No 27 done
# 15
# Page No 28 done
# 15
# Page No 29 done
# 15
# Page No 30 done
# 15
# Page No 31 done
# 15
# Page No 32 done
# 15
# Page No 33 done
# 15
# Page No 34 done
# 15
# Page No 35 done
# 15
# Page No 36 done
# 15
# Page No 37 done
# 15
# Page No 38 done
# 15
# Page No 39 done
# 15
# Page No 40 done
# 15
# Page No 41 done
# 15
# Page No 42 done
# 15
# Page No 43 done
# 15
# Page No 44 done
# 15
# Page No 45 done
# 15
# Page No 46 done
# 15
# Page No 47 done
# 15
# Page No 48 done
# 15
# Page No 49 done
# 15
# Page No 50 done
# 15
# Page No 51 done
# 15
# Page No 52 done
# 15
# Page No 53 done
# 15
# Page No 54 done
# 15
# Page No 55 done
# 15
# Page No 56 done
# 15
# Page No 57 done
# 15
# Page No 58 done
# 15
# Page No 59 done
# 15
# Page No 60 done
# 15
# Page No 61 done
# 15
# Page No 62 done
# 15
# Page No 63 done
# 15
# Page No 64 done
# 15
# Page No 65 done
# 15
# Page No 66 done
# 15
# Page No 67 done
# 15
# Page No 68 done
# 15
# Page No 69 done
# 15
# Page No 70 done
# 15
# Page No 71 done
# 15
# Page No 72 done
# 15
# Page No 73 done
# 15
# Page No 74 done
# 15
# Page No 75 done
# 15
# Page No 76 done
# 15
# Page No 77 done
# 15
# Page No 78 done
# 15
# Page No 79 done
# 15
# Page No 80 done
# 15
# Page No 81 done
# 0
# Process Done
# City:  kheda
# **************************************************
# 0
# Process Done
# City:  pune
# **************************************************
# 0
# Process Done
# City:  anand
# **************************************************
# 0
# Process Done
# City:  panchmahal
# **************************************************
# 0
# Process Done
# City:  gandhinagar
# **************************************************
# 0
# Process Done
# City:  surat
# **************************************************
