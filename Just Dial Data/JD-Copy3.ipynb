# %%
from JD import website
pages = 100

for city in ["ahmedabad", "mumbai","vadodara", "kheda", "pune", "anand", "panchmahal", "gandhinagar", "surat" ]:
    for i in range(1,pages):
        url = "https://www.justdial.com/"+ city +"/Salons-Men/nct-11099290/page-"+str(i)
        url_split = url.split("/")[3:]
        filename = url_split[0] + "_" + url_split[1]
        if len(website(url,filename)) == 0:
            print("Process Done")
            break
        print("Page No "+ str(i) +" done")
    print("City: ", city)
    print("*"*50)
# Out:
# 100
# Page No 1 done
# 90
# Page No 2 done
# 80
# Page No 3 done
# 70
# Page No 4 done
# 60
# Page No 5 done
# 50
# Page No 6 done
# 40
# Page No 7 done
# 30
# Page No 8 done
# 20
# Page No 9 done
# 10
# Page No 10 done
# 10
# Page No 11 done
# 10
# Page No 12 done
# 10
# Page No 13 done
# 10
# Page No 14 done
# 10
# Page No 15 done
# 10
# Page No 16 done
# 10
# Page No 17 done
# 10
# Page No 18 done
# 10
# Page No 19 done
# 10
# Page No 20 done
# 10
# Page No 21 done
# 10
# Page No 22 done
# 10
# Page No 23 done
# 10
# Page No 24 done
# 10
# Page No 25 done
# 10
# Page No 26 done
# 10
# Page No 27 done
# 10
# Page No 28 done
# 10
# Page No 29 done
# 10
# Page No 30 done
# 10
# Page No 31 done
# 10
# Page No 32 done
# 10
# Page No 33 done
# 10
# Page No 34 done
# 10
# Page No 35 done
# 10
# Page No 36 done
# 10
# Page No 37 done
# 10
# Page No 38 done
# 10
# Page No 39 done
# 10
# Page No 40 done
# 10
# Page No 41 done
# 10
# Page No 42 done
# 10
# Page No 43 done
# 10
# ...
